# %%
from matplotlib import pyplot
from sklearn.datasets import make_moons
from keras.models import Sequential
from keras.layers import Dense
X,Y=make_moons(n_samples=100,noise=0.2,random_state=1)
n_train=30
trainX,testX=X[:n_train,:],X[n_train:]
trainY,testY=Y[:n_train],Y[n_train:]
#print(trainX)
#print(trainY)
#print(testX) #print(testY)
model=Sequential()
model.add(Dense(500,input_dim=2,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
history=model.fit(trainX,trainY,validation_data=(testX,testY),epochs=10)
pyplot.plot(history.history['accuracy'],label='train')
pyplot.plot(history.history['val_accuracy'],label='test')
pyplot.legend()
pyplot.show()
# Out:
# Epoch 1/10
# 1/1 [==============================] - 1s 1s/step - loss: 0.7083 - accuracy: 0.2000 - val_loss: 0.6954 - val_accuracy: 0.4857
# Epoch 2/10
# 1/1 [==============================] - 0s 51ms/step - loss: 0.6924 - accuracy: 0.5333 - val_loss: 0.6852 - val_accuracy: 0.6000
# Epoch 3/10
# 1/1 [==============================] - 0s 59ms/step - loss: 0.6768 - accuracy: 0.7667 - val_loss: 0.6752 - val_accuracy: 0.6286
# Epoch 4/10
# 1/1 [==============================] - 0s 50ms/step - loss: 0.6616 - accuracy: 0.8667 - val_loss: 0.6655 - val_accuracy: 0.6286
# Epoch 5/10
# 1/1 [==============================] - 0s 67ms/step - loss: 0.6467 - accuracy: 0.8667 - val_loss: 0.6562 - val_accuracy: 0.6571
# Epoch 6/10
# 1/1 [==============================] - 0s 120ms/step - loss: 0.6322 - accuracy: 0.8333 - val_loss: 0.6471 - val_accuracy: 0.6857
# Epoch 7/10
# 1/1 [==============================] - 0s 101ms/step - loss: 0.6181 - accuracy: 0.8333 - val_loss: 0.6383 - val_accuracy: 0.6857
# Epoch 8/10
# 1/1 [==============================] - 0s 93ms/step - loss: 0.6043 - accuracy: 0.8333 - val_loss: 0.6298 - val_accuracy: 0.6857
# Epoch 9/10
# 1/1 [==============================] - 0s 93ms/step - loss: 0.5910 - accuracy: 0.8333 - val_loss: 0.6216 - val_accuracy: 0.6857
# Epoch 10/10
# 1/1 [==============================] - 0s 109ms/step - loss: 0.5779 - accuracy: 0.8333 - val_loss: 0.6137 - val_accuracy: 0.6857

# %%
from matplotlib import pyplot
from sklearn.datasets import make_moons
from keras.models import Sequential
from keras.layers import Dense
from keras.regularizers import l2
X,Y=make_moons(n_samples=100,noise=0.2,random_state=1)
n_train=30
trainX,testX=X[:n_train,:],X[n_train:]
trainY,testY=Y[:n_train],Y[n_train:]
#print(trainX)
#print(trainY)
#print(testX) #print(testY)
model=Sequential()

model.add(Dense(500,input_dim=2,activation='relu'
,kernel_regularizer=l2(0.001)))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
history=model.fit(trainX,trainY,validation_data=(testX,testY),epochs=10)
pyplot.plot(history.history['accuracy'],label='train')
pyplot.plot(history.history['val_accuracy'],label='test')
pyplot.legend()
pyplot.show()
# Out:
# Epoch 1/10
# 1/1 [==============================] - 2s 2s/step - loss: 0.7015 - accuracy: 0.3333 - val_loss: 0.6945 - val_accuracy: 0.6143
# Epoch 2/10
# 1/1 [==============================] - 0s 63ms/step - loss: 0.6848 - accuracy: 0.8000 - val_loss: 0.6837 - val_accuracy: 0.6286
# Epoch 3/10
# 1/1 [==============================] - 0s 97ms/step - loss: 0.6685 - accuracy: 0.8667 - val_loss: 0.6733 - val_accuracy: 0.6429
# Epoch 4/10
# 1/1 [==============================] - 0s 128ms/step - loss: 0.6526 - accuracy: 0.8667 - val_loss: 0.6632 - val_accuracy: 0.6857
# Epoch 5/10
# 1/1 [==============================] - 0s 45ms/step - loss: 0.6372 - accuracy: 0.8333 - val_loss: 0.6535 - val_accuracy: 0.6857
# Epoch 6/10
# 1/1 [==============================] - 0s 65ms/step - loss: 0.6223 - accuracy: 0.8333 - val_loss: 0.6442 - val_accuracy: 0.6857
# Epoch 7/10
# 1/1 [==============================] - 0s 63ms/step - loss: 0.6078 - accuracy: 0.8333 - val_loss: 0.6352 - val_accuracy: 0.6857
# Epoch 8/10
# 1/1 [==============================] - 0s 48ms/step - loss: 0.5937 - accuracy: 0.8333 - val_loss: 0.6266 - val_accuracy: 0.6857
# Epoch 9/10
# 1/1 [==============================] - 0s 65ms/step - loss: 0.5801 - accuracy: 0.8333 - val_loss: 0.6184 - val_accuracy: 0.6857
# Epoch 10/10
# 1/1 [==============================] - 0s 70ms/step - loss: 0.5669 - accuracy: 0.8333 - val_loss: 0.6105 - val_accuracy: 0.6857

# %%
from matplotlib import pyplot
from sklearn.datasets import make_moons
from keras.models import Sequential
from keras.layers import Dense
from keras.regularizers import l1_l2
X,Y=make_moons(n_samples=100,noise=0.2,random_state=1)
n_train=30
trainX,testX=X[:n_train,:],X[n_train:]
trainY,testY=Y[:n_train],Y[n_train:]
#print(trainX)
#print(trainY)
#print(testX)
#print(testY)

model=Sequential()
model.add(Dense(500,input_dim=2,activation='relu',kernel_regularizer=l1_l2(l1=0.001,l2=0.001)))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
history=model.fit(trainX,trainY,validation_data=(testX,testY),epochs=10)
pyplot.plot(history.history['accuracy'],label='train')
pyplot.plot(history.history['val_accuracy'],label='test')
pyplot.legend()
pyplot.show()
# Out:
# Epoch 1/10
# 1/1 [==============================] - 1s 603ms/step - loss: 0.7390 - accuracy: 0.7667 - val_loss: 0.7333 - val_accuracy: 0.7429
# Epoch 2/10
# 1/1 [==============================] - 0s 29ms/step - loss: 0.7229 - accuracy: 0.9000 - val_loss: 0.7229 - val_accuracy: 0.7286
# Epoch 3/10
# 1/1 [==============================] - 0s 26ms/step - loss: 0.7071 - accuracy: 0.9000 - val_loss: 0.7129 - val_accuracy: 0.7286
# Epoch 4/10
# 1/1 [==============================] - 0s 30ms/step - loss: 0.6919 - accuracy: 0.9000 - val_loss: 0.7032 - val_accuracy: 0.7286
# Epoch 5/10
# 1/1 [==============================] - 0s 30ms/step - loss: 0.6771 - accuracy: 0.9000 - val_loss: 0.6939 - val_accuracy: 0.7286
# Epoch 6/10
# 1/1 [==============================] - 0s 45ms/step - loss: 0.6627 - accuracy: 0.9000 - val_loss: 0.6849 - val_accuracy: 0.7143
# Epoch 7/10
# 1/1 [==============================] - 0s 48ms/step - loss: 0.6488 - accuracy: 0.9000 - val_loss: 0.6763 - val_accuracy: 0.7143
# Epoch 8/10
# 1/1 [==============================] - 0s 29ms/step - loss: 0.6353 - accuracy: 0.9000 - val_loss: 0.6680 - val_accuracy: 0.7143
# Epoch 9/10
# 1/1 [==============================] - 0s 45ms/step - loss: 0.6222 - accuracy: 0.9000 - val_loss: 0.6601 - val_accuracy: 0.7143
# Epoch 10/10
# 1/1 [==============================] - 0s 47ms/step - loss: 0.6095 - accuracy: 0.9000 - val_loss: 0.6524 - val_accuracy: 0.7143
